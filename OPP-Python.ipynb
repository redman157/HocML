# %% [markdown]
# <a href="https://colab.research.google.com/github/redman157/HocML/blob/master/OPP-Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_digits
from sklearn.metrics import mean_squared_error, r2_score

# %%
digits = load_digits()

# %%
digits.data
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
class MyLR:
  def __init__(self,X,y,model,weight,bias):
    self.data = X
    self.target = y
    self.model = model
    self.weight = W
    self.bias = np.zeros(shape=[weight.shape[0]])
    
  def fit(self,X,y,weight):
    # neu fit_intercept = True thi add bias vao
    XT = np.dot(X.T,y)
    inv_X = np.linalg.inv(XT)
    YT = np.dot(inv_X,y)
    weight = np.dot(inv_XT,YT)
  
  def pred(self,X,fit):
    return self.bias + np.dot(X,weight)
  
  def sigmoid(self,pred):
    return 1/(1+np.exp(-(pred)))

# %%
class backward:
  def __init__(self,X,y,model):
    self.data = X
    self.target = y
    self.model = model
  def cross_entropy(self):
    self.cross = np.mean((self.model.pred(self.X) - self.y) **2)
    return self.cross
# Out:
#   File "<ipython-input-5-d03fa34429a1>", line 2
#     def __init__(self,X,y,model):
#                                  ^
# SyntaxError: unexpected EOF while parsing

# %%
class Metrics:
  def __init__(self,X,y,model):
    self.data = X
    self.target = y
    self.model = model
    # goi model lên để train
    # khởi tao gia trị variable variance
    self._dft = X.shape[0] - 1
    # khởi tạo giá trị error variance
    self._dfe = X.shape[0] - X.shape[1] - 1
  def mse(self):
    # mse = gia tri trung binh 1/can 2 (can bac 2 ( pred - target))
    self.mse_ = np.mean((self.model.predict(self.data) - self.target) ** 2 )
    return self.mse_

# %%
lr = LinearRegression()
lr.fit(data,target)
mean_squared_error(target,lr.predict(data))
# Out:
# 21.894831181729202

# %%
mlr = MyLinearRegression()
mlr.fit(data ,target)
pred = mlr.predict(data)

# %%
metrics = Metrics(data,target,mlr)
metrics.mse()
# Out:
# 21.894831181729206

# %%
def ols(X, y):
    '''returns parameters based on Ordinary Least Squares.'''
    xtx = np.dot(X.T, X) ## x-transpose times x
    inv_xtx = np.linalg.inv(xtx) ## inverse of x-transpose times x
    xty = np.dot(X.T, y) ## x-transpose times y
    return np.dot(inv_xtx, xty)
  
parameters = ols(X,y)
predictions = np.dot(X_new, parameters)

# %%
# Out:
# ...
