# %% [markdown]
# <a href="https://colab.research.google.com/github/redman157/HocML/blob/master/baitapvn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# hiển thi menu thục hiện chức năng sau
# 1 nhâp vào số tiến gốc ban đầu
# 2 nhap vao so thang gửi tiền
# 3 nhâp vào lãi suất hàng tháng
# 4 tính số tiền nhận được sau mỗi tháng thưởng , nếu 1 2 3 người dùng chưa nhập thì thông báo lỗi và dừng chương trình
# nếu a bc nhận thì bắt đầu tính mục theo quy tắc sau ( cái này t làm dc chỉ ghi phần trên)
import sys
print('Nhập vào số tiền gốc ban đầu')
try:
  tienGoc = int(input())
except:
  ValueError: print("Vui Long Nhập Dữ liệu \n")
  sys.exit(1)
  
print('Nhập vào số tháng gửi tiền')
try:
  soThang = int(input())
except:
  ValueError: print("Vui Long Nhập Dữ liệu \n") 
  sys.exit(1)  
print('Nhập vào lãi suất hàng tháng')
try:
  lai = int(input())
except:
  ValueError: print("Vui Long Nhập Dữ liệu") 
  sys.exit(1)
  
def checkMoney(tienGoc, soThang, lai):
  for i in range(0, soThang ):    
    tienGoc = (tienGoc + ((lai / 100) * tienGoc))
    print(f'Tháng Thứ {i} khá sẽ nhận là sẽ nhận là: {tienGoc}')

def checkLai(tienGoc, soThang, ):
  tong = 0
  lai = tienGoc - tienLai
  for i in range(0, soThang ): 
    tienGoc = (tienGoc + ((lai / 100) * tienGoc))
    print(f'Tháng Thứ {i} khá sẽ nhận là sẽ nhận là: {lai}')
# Out:
# Nhập vào số tiền gốc ban đầu
# a
# Vui Long Nhập Dữ liệu
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
checkMoney(1000, 4, 2)

# %%
# sử dụng danh sach lien kết đơn giải quyết bài toán
# hiển thi menu gồm chức năng sau
# a.nhập số lượng khách hàng
# nếu chọn mục a, thông bao cho người dùng biết chọn mục a, và hiển thị lai menu, nếu chọn mục a, hãy cho người dùng thấy thông tin khách hàng : mã khạch hàng, tên khách hàng
# lãi suất tháng ,thời gian gửi, tổng số tiền đã gửi sau n tháng


# xây dựng menu a hãy xuất tiền gốc ban đầu khách hàng 
# bằng cách thông lấy thông tin tổng tiền n tháng, lãi suất, số tháng
# ví dụ tổng tiền gửi = tiền gốc +( lãi suất * tiền gốc ) sau 1 tháng
 # ví dụ  sau 3 tháng 
  #100 + (2% * 100) = 102 
       # 102 + (2% * 100) = 104 
       # 104 + (2% * 100 ) = 106

# %%
try:
  soLuongKH = int(input())
except:
  ValueError: print("Vui Lòng Nhập Số lượng khách hàng trước đã ") 
  sys.exit(1)

# %%
class ThongTin:
   def __init__(self, makh, tenkh, laiSuat, thoiGian, tongTien ):
    self.makh = makh
    self.tenkh = tenkh
    self.laiSuat = laiSuat
    self.thoiGian = thoiGian
    self.tongTien = tongTien
    self.next = None
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None
    
class danhSach:
  def __init__(self):
    self.head = None
    self.tail = None
  
  def add(self , ThongTin):
    node = Node(ThongTin)
    node.next = self.tail
    
    self.tail = node
    if self.head is None:
	    self.head = node
   
  def get(self, index):
    current = self.head
    for step in range(0, index):
			if curr is None:
				return None
			else:
				curr = curr.next
		else:
			return curr.data

# %%
class Record:
	def __init__(self, id, name, rate, timesaving, sumup):
		self.id = id
		self.name = name 
		self.rate = rate
		self.timesaving = timesaving
		self.sumup = sumup

class Node:
	def __init__(self, data):
		self.data = data
		self.next = None

class LinkedList:
	def __init__(self):
		self._head = None
		self._tail = None

	def push(self, record):
		node = Node(record)
		node.next = self._tail

		self._tail = node
		if self._head is None:
			self._head = node

	@property
	def head(self):
		return self._head

	@property
	def tail(self):
		return self._tail
	
	def get(self, index):
		curr = self._head

		for _ in range(0, index):
			if curr is None:
				return None
			else:
				curr = curr.next
		else:
			return curr.data

def menu():	
	print("Menu:")

	while True:
		print("a/ Thêm một khách hàng mới")
		print("b/ Hiển thị danh sách khách hàng")
		print("c/ Kết thúc")
		print("")

		result = input("Nhập lệnh thực thi:")
		if result == "a":
      
			return 1
		elif result == "b":
			return 2
		elif result == "c":
			return 3
		else:
			print("Làm ơn kiểm tra lại mã lệnh và nhập lại theo hướng dẫn sau")

def main():
	llist = LinkedList()
	while True:
    
    cmd = menu()
    
    if cmd == 3:
			print("Cám ơn đã sử dụng dịch vụ của chúng tôi, tạm biệt")
			sys.exit(0)
		elif cmd == 2:
			curr = llist.head
      
			print("ID\tTên\Lãi suất\tThời gian gửi\tTổng số tiền")
			while curr != None and curr != llist.tail.next:
				rec = curr.data
				print(rec.id, rec.name, rec.rate, rec.timesaving, rec.sumup)
				curr = curr.next
		else:
      print('Vui long nhập số lượng khách hàng: ')
      soluongKh = int(input())
      for step in range(0, soluongKh):
        id = input("Nhập id: ")
        name = input("Nhập tên: ")
			  rate = float(input("Nhập lãi suất: "))
			  timesaving = int(input("Nhập số tháng gửi: "))
			  sumup = (timesaving*rate + 1.0)*float(input("Nhập sỗ tiền gửi ban đầu: "))
			  llist.push(Record(id, name, rate, timesaving, sumup))

if __name__ == '__main__':
	main()
# Out:
#   File "<ipython-input-73-5098677efd39>", line 70
#     cmd = menu()
#                 ^
# IndentationError: unindent does not match any outer indentation level

# %%
import sys

class Record:
	def __init__(self, id, name, rate, timesaving, sumup):
		self.id = id
		self.name = name 
		self.rate = rate
		self.timesaving = timesaving
		self.sumup = sumup

class Node:
	def __init__(self, data):
		self.data = data
		self.next = None

class LinkedList:
	def __init__(self):
		self._head = None
		self._tail = None

	def push(self, record):
		node = Node(record)
		node.next = self._tail

		self._tail = node
		if self._head is None:
			self._head = node

	@property
	def head(self):
		return self._head

	@property
	def tail(self):
		return self._tail
	
	def get(self, index):
		curr = self._head

		for _ in range(0, index):
			if curr is None:
				return None
			else:
				curr = curr.next
		else:
			return curr.data

def menu():	
	print("Menu:")

	while True:
		print("a/ Thêm một khách hàng mới")
		print("b/ Hiển thị danh sách khách hàng")
		print("c/ Kết thúc")
		print("")

		result = input("Nhập lệnh thực thi:")
		if result == "a":
			return 1
		elif result == "b":
			return 2
		elif result == "c":
			return 3
		else:
			print("Làm ơn kiểm tra lại mã lệnh và nhập lại theo hướng dẫn sau")

def main():
	llist = LinkedList()

	while True:
		cmd = menu()

		if cmd == 3:
			print("Cám ơn đã sử dụng dịch vụ của chúng tôi, tạm biệt")
			sys.exit(0)
		elif cmd == 2:
			curr = llist.head
			n = int(input("Nhập số lượng khách hàng: "))

			print("ID\tTên\tLãi suất\tThời gian\tTiền gốc\tTiền sẽ nhận ")
			while curr != None and curr != llist.tail.next and n >= 0:
				rec = curr.data
				print("%s\t%s\t%f\t%d\t%f" % (rec.id, rec.name, rec.rate, rec.timesaving, rec.sumup))
				curr = curr.next
				n -= 1
		else:
			id = input("Nhập id: ")
			name = input("Nhập tên: ")
			rate = float(input("Nhập lãi suất: "))
			timesaving = int(input("Nkhập số tháng gửi: "))
			sumup = (timesaving*rate + 1.0)*float(input("Nhập sỗ tiền gửi ban đầu: "))

			llist.push(Record(id, name, rate, timesaving, sumup))

if __name__ == '__main__':
	main()
# Out:
# Menu:
# a/ Thêm một khách hàng mới
# b/ Hiển thị danh sách khách hàng
# c/ Kết thúc
#
# Nhập lệnh thực thi:a
# Nhập id: 11
# Nhập tên: pham son
# Nhập lãi suất: 3
# Nkhập số tháng gửi: 4
# Nhập sỗ tiền gửi ban đầu: 1000
# Menu:
# a/ Thêm một khách hàng mới
# b/ Hiển thị danh sách khách hàng
# c/ Kết thúc
#
# Nhập lệnh thực thi:a
# Nhập id: 12
# Nhập tên: an khang
# Nhập lãi suất: 2
# Nkhập số tháng gửi: 5
# Nhập sỗ tiền gửi ban đầu: 100
# Menu:
# a/ Thêm một khách hàng mới
# b/ Hiển thị danh sách khách hàng
# c/ Kết thúc
#
# Nhập lệnh thực thi:13
# Làm ơn kiểm tra lại mã lệnh và nhập lại theo hướng dẫn sau
# a/ Thêm một khách hàng mới
# b/ Hiển thị danh sách khách hàng
# c/ Kết thúc
#
# Nhập lệnh thực thi:b
# Nhập số lượng khách hàng: 2
# ID	Tên	Lãi suất	Thời gian	Tiền gốc	Tiền sẽ nhận
# Menu:
# a/ Thêm một khách hàng mới
# b/ Hiển thị danh sách khách hàng
# c/ Kết thúc
#
# Nhập lệnh thực thi:a
# Nhập id: 8
# Nhập tên: thuc tuan
# Nhập lãi suất: 7
# Nkhập số tháng gửi: 7
# ...

# %%
lk = LinkedList()
lk.add("ms10", "phamson", 10, 2, 300)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-bb66cb47b7d4> in <module>()
#       1 lk = LinkedList()
# ----> 2 lk.add("ms10", "phamson", 10, 2, 300)
#
# TypeError: add() takes 2 positional arguments but 6 were given

# %%
import sys

class Record:
    def __init__(self, id, name, rate, timesaving, sumup):
        self.id = id
        self.name = name 
        self.rate = rate
        self.timesaving = timesaving
        self.sumup = sumup

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self._head = None
        self._tail = None

    def push(self, record):
        node = Node(record)
        node.next = self._tail

        self._tail = node
        if self._head is None:
            self._head = node

    @property
    def head(self):
        return self._head

    @property
    def tail(self):
        return self._tail
    
    def get(self, index):
        curr = self._head

        for _ in range(0, index):
            if curr is None:
                return None
            else:
                curr = curr.next
        else:
            return curr.data

def menu(): 
    print("Menu:")

    while True:
        print("a/ Thêm một khách hàng mới")
        print("b/ Hiển thị danh sách khách hàng")
        print("c/ Kết thúc")
        print("")

        result = input("Nhập lệnh thực thi:")
        if result == "a":
            return 1
        elif result == "b":
            return 2
        elif result == "c":
            return 3
        else:
            print("Làm ơn kiểm tra lại mã lệnh và nhập lại theo hướng dẫn sau")

def main():
    llist = LinkedList()

    while True:
        cmd = menu()

        if cmd == 3:
            print("Cám ơn đã sử dụng dịch vụ của chúng tôi, tạm biệt")
            sys.exit(0)
        elif cmd == 2:
            curr = llist.head
            print("ID\tTên\tLãi suất\tThời gian\tTiền gốc\tTiền sẽ nhận ")
            
            if curr != None and curr != llist.tail.next :
              rec = curr.data
              print("%s\t%s\t%f\t%d\t%f" % (rec.id, rec.name, rec.rate, rec.timesaving, rec.sumup))
              curr = curr.next
                
        else:
            soluongkh = int(input("nhap so luong khách hàng: "))
            for i in range(0,soluongkh):
              print("\n")
              id = input("Nhập id: ")
              name = input("Nhập tên: ")
              rate = float(input("Nhập lãi suất: "))
              timesaving = int(input("Nhập số tháng gửi: "))
              sumup = float(input("Nhập sỗ tiền gửi ban đầu: "))/ (timesaving**(rate + 1.0))
              llist.push(Record(id, name, rate, timesaving, sumup))

if __name__ == '__main__':
    main()
# Out:
# Menu:
# a/ Thêm một khách hàng mới
# b/ Hiển thị danh sách khách hàng
# c/ Kết thúc
#
# Nhập lệnh thực thi:a
# nhap so luong khách hàng: 2
# Nhập id: 8
# Nhập tên: pham son
# Nhập lãi suất: 3
# Nhập số tháng gửi: 4
# Nhập sỗ tiền gửi ban đầu: 1000
# Nhập id: 9
# Nhập tên: an khang
# Nhập lãi suất: 4
# Nhập số tháng gửi: 2
# Nhập sỗ tiền gửi ban đầu: 900
# Menu:
# a/ Thêm một khách hàng mới
# b/ Hiển thị danh sách khách hàng
# c/ Kết thúc
#
# Nhập lệnh thực thi:b
# Nhập số lượng khách hàng: 2
# ID	Tên	Lãi suất	Thời gian	Tiền gốc	Tiền sẽ nhận
# Menu:
# a/ Thêm một khách hàng mới
# b/ Hiển thị danh sách khách hàng
# c/ Kết thúc
#
# Nhập lệnh thực thi:c
# Cám ơn đã sử dụng dịch vụ của chúng tôi, tạm biệt
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import sys

class Record:
    def __init__(self, id, name, rate, timesaving, sumup):
        self.id = id
        self.name = name 
        self.rate = rate
        self.timesaving = timesaving
        self.sumup = sumup

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self._head = None
        self._tail = None

    def push(self, record):
        node = Node(record)
        node.next = self._tail

        if self._tail is None:
            self._tail = node
        else:
            self._tail.next = node
        if self._head is None:
            self._head = node


    def show(self):
        curr = self._head
        while curr != None:
            print(curr, curr.next)
            curr = curr.next

    @property
    def head(self):
        return self._head

    @property
    def tail(self):
        return self._tail
    
    def get(self, index):
        curr = self._head

        for _ in range(0, index):
            if curr is None:
                return None
            else:
                curr = curr.next
        else:
            return curr.data

def menu(): 
    print("Menu:")

    while True:
        print("a/ Thêm một khách hàng mới")
        print("b/ Hiển thị danh sách khách hàng")
        print("c/ Kết thúc")
        print("")

        result = input("Nhập lệnh thực thi:")
        if result == "a":
            return 1
        elif result == "b":
            return 2
        elif result == "c":
            return 3
        else:
            print("Làm ơn kiểm tra lại mã lệnh và nhập lại theo hướng dẫn sau")

def main():
    llist = LinkedList()

    while True:
        cmd = menu()

        if cmd == 3:
            print("Cám ơn đã sử dụng dịch vụ của chúng tôi, tạm biệt")
            sys.exit(0)
        elif cmd == 2:
            curr = llist.head
   
            print("ID\tTên\tLãi suất\tThời gian\tTiền gốc\tTiền sẽ nhận ")
            while curr != None:
              rec = curr.data
              print("%s\t%s\t%f\t%d\t%f" % (rec.id, rec.name, rec.rate, rec.timesaving, rec.sumup))
              curr = curr.next
        else:
            soluongkh = int(input("nhap so luong khách hàng: "))
            for i in range(0,soluongkh):
              print("\n")
              id = input("Nhập id: ")
              name = input("Nhập tên: ")
              rate = float(input("Nhập lãi suất: "))
              timesaving = int(input("Nhập số tháng gửi: "))
              sumup = float(input("Nhập sỗ tiền gửi ban đầu: "))/ (timesaving**(rate + 1.0))

              llist.push(Record(id, name, rate, timesaving, sumup))

if __name__ == '__main__':
    main()

# %%
import sys

class Record:
    def __init__(self, id, name, rate, timesaving, sumup):
        self.id = id
        self.name = name 
        self.rate = rate
        self.timesaving = timesaving
        self.sumup = sumup

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self._head = None
        self._tail = None

    def push(self, record):
        node = Node(record)
        node.next = self._tail

        if self._tail is None:
            self._tail = node
        else:
            self._tail.next = node
        if self._head is None:
            self._head = node

    def show(self):
        curr = self._head
        while curr != None:
            print(curr, curr.next)
            curr = curr.next

    @property
    def head(self):
        return self._head

    @property
    def tail(self):
        return self._tail
    
    def get(self, index):
        curr = self._head

        for _ in range(0, index):
            if curr is None:
                return None
            else:
                curr = curr.next
        else:
            return curr.data

def menu(): 
    print("Menu:")

    while True:
        print("a/ Thêm một khách hàng mới")
        print("b/ Hiển thị danh sách khách hàng")
        print("c/ Kết thúc")
        print("")

        result = input("Nhập lệnh thực thi:")
        if result == "a":
            return 1
        elif result == "b":
            return 2
        elif result == "c":
            return 3
        else:
            print("Làm ơn kiểm tra lại mã lệnh và nhập lại theo hướng dẫn sau")

def main():
    llist = LinkedList()

    while True:
        cmd = menu()

        if cmd == 3:
            print("Cám ơn đã sử dụng dịch vụ của chúng tôi, tạm biệt")
            sys.exit(0)
        elif cmd == 2:
            curr = llist.head

            print("ID\tTên\tLãi suất\tThời gian\tTiền gốc\")
            while curr != None and curr != llist.tail.next:
                rec = curr.data
                print("%s\t%s\t%f\t%d\t%f" % (rec.id, rec.name, rec.rate, rec.timesaving, rec.sumup))
                curr = curr.next
        else:
            n = int(input("Nhập số lượng khách hàng: "))
            for i in range(n):
                print("Nhập thông tin khách hàng thứ %d:" % i)
                id = input("\tNhập id: ")
                name = input("\tNhập tên: ")
                rate = float(input("\tNhập lãi suất: "))
                timesaving = int(input("\tNkhập số tháng gửi: "))
                sumup = float(input("\tNhập sỗ tiền gửi ban đầu: ")) / (timesaving*rate + 1.0)

                llist.push(Record(id, name, rate, timesaving, sumup))

if __name__ == '__main__':
    main()
# Out:
# Menu:
# a/ Thêm một khách hàng mới
# b/ Hiển thị danh sách khách hàng
# c/ Kết thúc
#
# Nhập lệnh thực thi:a
# Nhập số lượng khách hàng: 2
# Nhập thông tin khách hàng thú 0:
# 	Nhập id: 1
# 	Nhập tên: pham son
# 	Nhập lãi suất: 2
# 	Nkhập số tháng gửi: 8
# Nhập sỗ tiền gửi ban đầu: 1000
# Nhập thông tin khách hàng thú 1:
# 	Nhập id: 2
# 	Nhập tên: pham kang
# 	Nhập lãi suất: 3
# 	Nkhập số tháng gửi: 7
# Nhập sỗ tiền gửi ban đầu: 800
# Menu:
# a/ Thêm một khách hàng mới
# b/ Hiển thị danh sách khách hàng
# c/ Kết thúc
#
# Nhập lệnh thực thi:b
# ID	Tên	Lãi suất	Thời gian	Tiền gốc	Tiền sẽ nhận
# 1	pham son	2.000000	8	58.823529
# Menu:
# a/ Thêm một khách hàng mới
# b/ Hiển thị danh sách khách hàng
# c/ Kết thúc
#
# Nhập lệnh thực thi:c
# Cám ơn đã sử dụng dịch vụ của chúng tôi, tạm biệt
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# ...
