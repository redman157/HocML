# %% [markdown]
# <a href="https://colab.research.google.com/github/redman157/HocML/blob/master/collection-data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests as rq
import re
import settings 
import json

def get_info_by_id(user, movies):
  pass
def collect_rss_movies():
  genres = settings.GENRES
  countries = settings.CONTRIES
  results = {}
  rss_url = 'https://rss.itunes.apple.com/api/v1/%s/movies/top-movies/%s/200/explicit.json'
  
  print('Getting iTunes data...')
  
  for country in countries:
    country_result = []
    for genre in genres:
      r = rq.get(rss_url % (country,genre)).json
      genre_results = r['feed']['results']
      country_results += genre_results   
      results[country]=country_results

      print('%d movies indexed from %s iTunes Store' %((len(results[country]),country.upper())))
        
  return results

# %%
import requests as rq
import re

url = 'https://api.github.com/user'
#r = rq.get(url , auth = 'user', 'pass'))
r = rq.post('https://httpbin.org/post', data = {'key':'value'})
r = rq.delete('https://httpbin.org/delete')
r = rq.head('https://httpbin.org/get')
r = rq.options('https://httpbin.org/get')

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = rq.get('https://httpbin.org/get', params=payload)

# %%
r = rq.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"9260086686","type":"PushEvent","actor":{"id":19422004,"login":"GrahamGunlock","display_login":"GrahamGunlock","gravatar_id":"","url":"https://api.github.com/users/GrahamGunlock","avatar_url":"https://avatars.githubusercontent.com/u/19422004?"},"repo":{"id":169666966,"name":"GrahamGunlock/Anvil","url":"https://api.github.com/repos/GrahamGunlock/Anvil"},"payload":{"push_id":3409857976,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"e631fc64ba2e0c0e7b7429c83f921c1733cbe8ee","before":"6dd216130c23ef44e4c8099b01e5f73c5b3d1c50","commits":[{"sha":"e631fc64ba2e0c0e7b7429c83f921c1733cbe8ee","author":{"email":"gegunlock@gmail.com","name":"Graham Gunlock"},"message":"Delete VMTableHook.cpp","distinct":true,"url":"https://api.github.com/repos/GrahamGunlock/Anvil/commits/e631fc64ba2e0c0e7b7429c83f921c1733cbe8ee"}]},"public":true,"created_at":"2019-03-18T03:37:58Z"},{"id":"9260086683","type":"PushEvent","actor":{"id":13705644,"login":"toyboxman","display_login":"toyboxman","gravatar_id":"","url":"https://api.github.com/users/toyboxman","avatar_url":"https://avatars.githubusercontent.com/u/13705644?"},"repo":{"id":40398682,"name":"toyboxman/yummy-xml-UI","url":"https://api.github.com/repos/toyboxman/yummy-xml-UI"},"payload":{"push_id":3409857973,"size":1,"distinct_size":1,"ref":"refs/heads/finalWord","head":"2121008e40dde53815dc4d3fa6c3daf83e58ad53","before":"6f187c92866fc827bfe6fb8c6eb6fea550546c67","commits":[{"sha":"2121008e40dde53815dc4d3fa6c3daf83e58ad53","author":{"email":"toyboxman@sina.com","name":"Eugene"},"message":"update document","distinct":true,"url":"https://api.github.com/repos/toyboxman/yummy-xml-UI/commits/2121008e40dde53815dc4d3fa6c3daf83e58ad53"}]},"public":true,"created_at":"2019-03-18T03:37:58Z"},{"id":"9260086681","type":"PushEvent","actor":{"id":26247762,"login":"hongyu789","display_login":"hongyu789","gravatar_id":"","url":"https://api.github.com/users/hongyu789","avatar_url":"https://avatars.githubusercontent.com/u/26247762?"},"repo":{"id":175577032,"name":"hongyu789/repo","url":"https://api.github.com/repos/hongyu789/repo"},"payload":{"push_id":3409857972,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"200ca635d8eb1e868ad9dfc5f391f8f22a8770ba","before":"d679b7583436ef14b9b130ac74585962eaf1c0d7","commits":[{"sha":"200ca635d8eb1e868ad9dfc5f391f8f22a8770ba","author":{"email":"hongyu789@163.com","name":"hongyu789"},"message":"Update neo-config-dev.properties","distinct":true,"url":"https://api.github.com/repos/hongyu789/repo/commits/200ca635d8eb1e868ad9dfc5f391f8f22a8770ba"}]},"public":true,"created_at":"2019-03-18T03:37:58Z"},{"id":"9260086669","type":"PushEvent","actor":{"id":6454443,"login":"zefram-cochrane","display_login":"zefram-cochrane","gravatar_id":"","url":"https://api.github.com/users/zefram-cochrane","avatar_url":"https://avatars.githubusercontent.com/u/6454443?"},"repo":{"id":40288475,"name":"zefram-cochrane/Zefram-Cochrane.github.io","url":"https://api.github.com/repos/zefram-cochrane/Zefram-Cochrane.github.io"},"payload":{"push_id":3409857964,"size":1,"distinct_size":1,"ref":"refs/heads/pull6","head":"658818796d7fbdb64765d2000441261dc3ab25ad","before":"cd61a2e5d5e2eaabeffcf57420c4b82e0de5ec2f","commits":[{"sha":"658818796d7fbdb64765d2000441261dc3ab25ad","author":{"email":"peter.merel@me.com","name":"Peter Merel"},"message":"Content updated via GitServer","distinct":true,"url":"https://api.github.com/repos/zefram-cochrane/Zefram-Cochrane.github.io/commits/658818796d7fbdb64765d2000441261dc3ab25ad"}]},"public":true,"created_at":"2019-03-18T03:37:58Z"},{"id":"9260086670","type":"WatchEvent","actor":{"id":30832295,"login":"wanglemon2008","display_login":"wanglemon2008","gravatar_id":"","url":"https://api.github.com/users/wanglemon2008","avatar_url":"https://avatars.githubusercontent.com/u/30832295?"},"repo":{"id":165207927,"name":"RanChuan/STM32_IAP","url":"https://api.github.com/repos/RanChuan/STM32_IAP"},"payload":{"action":"started"},"public":true,"created_at":"2019-03-1 ...
